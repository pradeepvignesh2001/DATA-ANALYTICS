# %% [markdown]
# **Import the required Modules:**

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **See the structure of URL:**

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url ='https://www.flipkart.com/search?q=apple+7&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=apple+7%7CMobiles&requestId=b52239fa-bafe-4c74-b8c7-cf9bdd3b79e6&as-searchtext=apple%207'

# %% [markdown]
# **Create List for store the Data**

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  48
# price =  48
# ratings =  48
# warranty =  48
# ratingsno = 48
# reviewsno =  48
# features =  48

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                         Product    Price Ratings  \
# 0               APPLE iPhone XR (White, 128 GB)  ₹44,999     4.6
# 1              APPLE iPhone XR (Yellow, 128 GB)  ₹44,999     4.6
# 2               APPLE iPhone XR (Black, 128 GB)  ₹44,999     4.6
# 3           APPLE iPhone 8 (Space Grey, 256 GB)  ₹77,000     4.5
# 4               APPLE iPhone 8 (Silver, 256 GB)  ₹77,000     4.5
# 5                 APPLE iPhone 8 (Gold, 256 GB)  ₹77,000     4.5
# 6            APPLE iPhone 7 Plus (Black, 32 GB)  ₹36,999     4.5
# 7        APPLE iPhone XR ((PRODUCT)RED, 128 GB)  ₹44,999     4.6
# 8                APPLE iPhone XR (Blue, 128 GB)  ₹44,999     4.6
# 9           APPLE iPhone 7 Plus (Black, 256 GB)  ₹85,400     4.5
# 10       APPLE iPhone 7 Plus (Rose Gold, 32 GB)  ₹36,999     4.5
# 11          APPLE iPhone 7 Plus (Black, 128 GB)  ₹42,900     4.5
# 12                APPLE iPhone SE (Red, 128 GB)  ₹29,999     4.5
# 13               APPLE iPhone 7 (Black, 128 GB)  ₹34,900     4.5
# 14                 APPLE iPhone 7 (Gold, 32 GB)  ₹24,999     4.5
# 15              APPLE iPhone XR (Coral, 128 GB)  ₹44,999     4.6
# 16         APPLE iPhone 7 Plus (Silver, 256 GB)  ₹85,400     4.5
# 17       APPLE iPhone 7 (PRODUCT) (Red, 256 GB)  ₹74,400     4.7
# 18            APPLE iPhone 7 (Jet Black, 32 GB)  ₹24,999     4.5
# 19           APPLE iPhone 7 Plus (Gold, 256 GB)  ₹85,400     4.5
# 20           APPLE iPhone 7 (Rose Gold, 128 GB)  ₹34,900     4.5
# 21          APPLE iPhone 7 Plus (Silver, 32 GB)  ₹36,999     4.5
# 22  APPLE iPhone 7 Plus (PRODUCT) (Red, 256 GB)  ₹85,400       5
# 23            APPLE iPhone 7 Plus (Red, 128 GB)  ₹42,900     4.5
# 24       APPLE iPhone XR ((PRODUCT)RED, 128 GB)  ₹44,999     4.6
# 25              APPLE iPhone XR (White, 128 GB)  ₹44,999     4.6
# 26             APPLE iPhone XR (Yellow, 128 GB)  ₹44,999     4.6
# 27              APPLE iPhone XR (Black, 128 GB)  ₹44,999     4.6
# 28          APPLE iPhone 8 (Space Grey, 256 GB)  ₹77,000     4.5
# 29              APPLE iPhone 8 (Silver, 256 GB)  ₹77,000     4.5
# 30                APPLE iPhone 8 (Gold, 256 GB)  ₹77,000     4.5
# 31           APPLE iPhone 7 Plus (Black, 32 GB)  ₹36,999     4.5
# 32               APPLE iPhone XR (Blue, 128 GB)  ₹44,999     4.6
# 33          APPLE iPhone 7 Plus (Black, 256 GB)  ₹85,400     4.5
# 34       APPLE iPhone 7 Plus (Rose Gold, 32 GB)  ₹36,999     4.5
# 35          APPLE iPhone 7 Plus (Black, 128 GB)  ₹42,900     4.5
# 36                APPLE iPhone SE (Red, 128 GB)  ₹29,999     4.5
# 37               APPLE iPhone 7 (Black, 128 GB)  ₹34,900     4.5
# 38                 APPLE iPhone 7 (Gold, 32 GB)  ₹24,999     4.5
# 39              APPLE iPhone XR (Coral, 128 GB)  ₹44,999     4.6
# 40         APPLE iPhone 7 Plus (Silver, 256 GB)  ₹85,400     4.5
# 41       APPLE iPhone 7 (PRODUCT) (Red, 256 GB)  ₹74,400     4.7
# 42            APPLE iPhone 7 (Jet Black, 32 GB)  ₹24,999     4.5
